# %%
list=[1,2,3,4]
print(list)
# Out:
# [1, 2, 3, 4]

# %%
list.append(5)#for addind element in the end of list
list
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
print(len(list))
# Out:
# 6

# %%
list.insert(7,6)
list
# Out:
# [1, 2, 3, 4, 5, 5, 6]

# %%
list.extend([1,2,3,4])
list
# Out:
# [1, 2, 3, 4, 5, 5, 6, 1, 2, 3, 4]

# %%
list.remove(2)#this is use to remove by value
list
# Out:
# [1, 3, 4, 5, 5, 6, 1, 2, 3, 4]

# %%
list.pop()#this is use to delete the element by the index value.no value means last value
list
# Out:
# [1, 3, 4, 5, 5, 6, 1, 2, 3]

# %%
list.pop(3)
list
# Out:
# [1, 3, 4, 6, 1, 2, 3]

# %%
list.clear()#this is for removing all elements from list
list
# Out:
# []

# %%
5 in list #for checking that elements exist or not
# Out:
# False

# %%
num=[2,3,4,5,6,1]
num.sort() #sorting in the ascending order
num
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
num.reverse() #sorting in the decending order
num
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
num.index(4) #finding the index
# Out:
# 2

# %%
num.count(3)#it counts the accurrence
# Out:
# 1

# %%
squares = []
for i in range(5):
    squares.append(i*i)
squares
# Out:
# [0, 1, 4, 9, 16]

# %%
squares = [i*i for i in range(5)] #list comprehension
